# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd drive/My Drive
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# /content/drive/My Drive

# %%
from pandas import read_csv
df = read_csv('text_classification/All_Dataset.csv',error_bad_lines=False)

# %%
from sklearn import model_selection
Train_X, Test_X, Train_Y, Test_Y = model_selection.train_test_split(df['text'],df['targe'],test_size=0.25)

# %%
print (Train_X)
# Out:
# 73416     أكدت مصادر من إدارة فريق نيس الفرنسي لـ هسبورت...
# 52171     أعلن سعد الدين العثماني رئيس الحكومة المكلف بت...
# 67881     السفري فرصة لجمع العائلة والوقوف على اختلالات ...
# 8449              طاقم البرنامج يبث تحقيقا صادما عن الموضوع
# 102546    عادت قضية القيمة الحقيقية لديون أولمبيك آسفي ل...
#                                 ...
# 62151     أخبارنا المغربية قال عبد الاله بنكيران رئيس ال...
# 25350     حلت الشرطة القضائية ببيت رئيس جماعة عين تاوجطا...
# 36564     عجز الميزانية يرتفع إلى مليار درهم في ثلاثة أش...
# 47670     أجرى جان إيف لودريان وزير أوروبا والشؤون الخار...
# 17472     متهم بتبديد المال العام والتزوير في محرر رسمي ...
# Name: text, Length: 83809, dtype: object

# %%
sentences = []
for sentence in df['text']:
  try: sentences.append(sentence.split(' '))
  except: pass

# %%
from gensim.models import Word2Vec, Doc2Vec

#model = Word2Vec(sentences, min_count=1)
#print(model)
#words = list(model.wv.vocab)
#print(words)

# %%
model.save('model.bin')
# Out:
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:402: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
new_model = Word2Vec.load('model.bin')
print(new_model)
# Out:
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:402: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# Word2Vec(vocab=423543, size=100, alpha=0.025)

# %%
X = model[model.wv.vocab]
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
result = pca.fit_transform(X)

# %%
from matplotlib import pyplot
pyplot.scatter(result[:, 0], result[:, 1])
words = list(model.wv.vocab)
for i, word in enumerate(words):
	pyplot.annotate(word, xy=(result[i, 0], result[i, 1]))
pyplot.show()
