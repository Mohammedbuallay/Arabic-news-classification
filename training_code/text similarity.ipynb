# %%
from google.colab import drive 
drive.mount('/content/drive')
# %cd drive/My Drive/text_classification
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# /content/drive/My Drive/text_classification

# %%
from collections import Counter
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
def get_cosine_sim(text1,text2): 
    vectors = get_vectors(text1,text2)
    return cosine_similarity(vectors)
    
def get_vectors(text1,text2):
    text = [text1,text2]
    print (text)
    vectorizer = CountVectorizer()
    vectorizer.fit(text)
    return vectorizer.transform(text).toarray()

# %%
get_cosine_sim('اسمه محمد بوعلاي ','اسمه خالد عبدالله عبدالرحمن')
# Out:
# ['اسمه محمد بوعلاي ', 'اسمه خالد عبدالله عبدالرحمن']
# [[1 1 0 0 0 1]
#  [1 0 1 1 1 0]]
# array([[1.        , 0.28867513],
#        [0.28867513, 1.        ]])

# %%
text1 = 'مصطفى الصوفي انطلقت أمس فعاليات الدورة الثالثة من مهرجان سلا الدولي للفنون الساخرة التي تنظمها جمعية نجمة للفكر والإبداع والتي تستمر على مدى ثلاثة أيام تحت شعار نضحكوها مغربية وشهد حفل الافتتاح الذي عرف تقديم كلمة مهمة لرئيسة الجمعية فوزية الوافي تكريم الثنائي سفاج ومهيول هذا الثنائي الذي اعتبرته مديرة المهرجان زهور الزرييق من الثنائيات الكوميدية الناجحة والرائعة التي قدمت طيلة مسيرتها الفنية فيضا من الأعمال التي خلقت الفرجة الكوميدية للجمهور وبالرغم من مرض واحد من الثنائي والمقبل على عملية جراحية حيث نتمنى له الشفاء العاجل لا أن الثنائي المحبوب حل إلى المركب الثقافي الملكي من اجل لقاء الجمهور لقاء تميز بالبساطة والود وشهادة مؤثرة ومميزة قدمها الفنان الساخر الشرقي الساروتي في حق المحتفى بهما واللذين تلقيا هدايا وتذكارات من يد رئيسة الجمعية ورئيسة الجماعة الحضرية كما تميزت الدورة أيضا بتكريم الفنان عبد الخالق فيهد فضلا عن سلسة من الفقرات الكوميدية التي سيؤديها نجوم الكوميديا من الجيل الصاعد الفائزين في المباراة الخاصة بانتقاء أحسن الكوميديين الشباب من بروع الوطن ومن مدينة سلا وتشكل هذه الدورة بالنظر إلى برمجتها حلقة استثنائية بطاقمها التنظيمي النسائي حرصا من مديرة المهرجان زهور الزرييق على تحقيق مقاربة النوع وإعطاء الفرصة للمرأة من أجل ابرزا قدراتها ودعمها ومشاركتها الفعالة في هذه الدورة التي تقام بشراكة مع مؤسسة سلا للثقافة والفنون وبدعم من وزارة الثقافة والمسرح الوطني وبريد المغرب وشركة اوبامي حيث يسعى الجميع إلى تبيان قدرات الشباب ومنحهم ثقة كبيرة في مواهبهم وفرصة مواتية للمشاركة إلى جانب نجوم الكوميديا كما تتنوع فقرات الدورة بين عروض فنية ساخرة فردية وثنائية وفن عروض الحلقة بساحة باب الخميس فضلا عن تنظيم ندوة فكرية في إطار صالون الزهراء لفنون القول نظمت أمس حول موضوع مظاهر الكتابة الساخرة في التراث الفني يديرها الدكتور عبد المجيد فنيش والدكتور محمد رمصيص مع قراءة في ديوان طرامواي للزجال مراد القادري وهي الندوة التي أبرزت دور الكوميديا والسخرية في معالجة القضايا الاجتماعية ومحاربة الاستعمار الفرنسي هذا فضلا عن فقرات عدة من أبرزها عرض مسرحية واش الغالية رخيصة من إخراج وتأليف الفنان المتميزة زهور الزرييق وبطولة فاطمة الزهراء أحرار وبنعبد الله الجندي وغيرهما في حفل الاختتام وهي المسرحية التي تعالج قضايا المرأة وقضايا اجتماعية عدة في قالب فني ساخر وجميل'
ة في ديوان طرامواي للزجال مراد القادري وهي الندوة التي أبرزت دور الكوميديا والسخرية في معالجة القضايا الاجتماعية ومحاربة الاستعمار الفرنسي هذا فضلا عن فقرات عدة من أبرزها عرض مسرحية واش الغالية رخيصة من إخراج وتأليف الفنان المتميزة زهور الزرييق وبطولة فاطمة الزهراء أحرار وبنعبد الله الجندي وغيرهما في حفل الاختتام وهي المسرحية التي تعالج قضايا المرأة وقضايا اجتماعية عدة في قالب فني ساخر وجميل', 'الاتحاد الاشتراكي تحيي الفنانة اللبنانية نجوى كرم وضيفة شرف مهرجان تيميتار بأكادير حفل الاختتام الذي سينظم يوم الخامس والعشرين من يونيو الجار وسينشط هذا الحفل إلى جانب نجوى كرم الفنانة الشعبية المغربية زينة الداودية يذكر أن الفنانة اللبنانية قررت طرح ألبومها الجديد يوم من الشهر الجاري بعد مجموعة كبيرة من التأجيلات ويتضمن الألبوم ثماني أغاني لبنانية متنوعة منها عيني بعينك لو بس تعرف دلل بياع اليانصيب التي ربما سيكون لجمهور تيميتار نصيب منها']
# [[1.         0.23670036]
#  [0.23670036 1.        ]]

# %%
# !pip install tashaphyne
# Out:
# Collecting tashaphyne
#   Downloading https://files.pythonhosted.org/packages/5f/80/8b94a7d91c92d252cc395d80ebf9e4b2fa5bdd0c3fbf10b4a1749817c998/Tashaphyne-0.3.4.1-py3-none-any.whl (244kB)
#      |████████████████████████████████| 245kB 12.6MB/s
# Collecting pyarabic
#   Downloading https://files.pythonhosted.org/packages/b8/77/da852ee13bce3affc55b746cebc0fdc0fc48628dbc5898ce489112cd6bd1/PyArabic-0.6.6.tar.gz (101kB)
#      |████████████████████████████████| 102kB 14.3MB/s
# Building wheels for collected packages: pyarabic
#   Building wheel for pyarabic (setup.py) ... done
#   Created wheel for pyarabic: filename=PyArabic-0.6.6-cp36-none-any.whl size=106210 sha256=80176bdf9a56cedde77b1c001d7c312d02d3c2d55af22b312ab3d76bba3d2a15
#   Stored in directory: /root/.cache/pip/wheels/34/b5/2d/668d567e8c2b6f10309dbfaba5bfef6ea0b1c0f9f6fb37078f
# Successfully built pyarabic
# Installing collected packages: pyarabic, tashaphyne
# Successfully installed pyarabic-0.6.6 tashaphyne-0.3.4.1

# %%
from collections import Counter
from sklearn.feature_extraction.text import CountVectorizer
from tashaphyne.stemming import ArabicLightStemmer
from sklearn.metrics.pairwise import cosine_similarity
import pickle
import pandas as pd
ArListem = ArabicLightStemmer()
def text_stem(input_text):
    temp_text=[]
    for word in input_text.split(" "):
        stem = ArListem.light_stem(word)
        stem = ArListem.get_stem()
        temp_text.append(stem)
    temp_text = pd.DataFrame([" ".join(temp_text)])  
    return temp_text

def get_sim_tfidf(text1,text2): 
    from sklearn.feature_extraction.text import TfidfVectorizer
    Tfidf_vect = TfidfVectorizer()
    text1_org= text1
    text1 = text_stem(text1)      
    text2 = text_stem(text2)
    Tfidf_vect.fit(text1[0]+text2[0])
    text1 = Tfidf_vect.transform(text1[0])
    text2 = Tfidf_vect.transform(text2[0])
    #print (text1,text2)
    return round(cosine_similarity(text1,text2)[0][0],2),text1_org

# %%
from pandas import read_csv
import pandas as pd
import concurrent.futures
import numpy as np

df = read_csv('processedDataset.csv',names=['txt','label'])
df = df.dropna()
new_df = []
for i in df['txt']:
    new_df.append(i)
list_of_simi=[]
print(new_df.pop())
def compare_all_dataset (x):
    for i in range(0,len(new_df),200):
        print (i)
        with concurrent.futures.ThreadPoolExecutor(max_workers=200) as executor:
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result())
            list_of_simi.append(executor.submit(get_sim_tfidf, new_df.pop(),x).result()) 
    acc_list,acc_list_word = [],[] 
    for i in range(len(list_of_simi)):
      acc_list.append(list_of_simi[i][0])
      acc_list_word.append(list_of_simi[i][1])    
    return acc_list_word[acc_list.index(max(acc_list))],max(acc_list)*100
# Out:
# رئيس تيزني ضغوط جماهير فريق استقال عامل إقليم نائب حفيظ روايس مقام استثنائ انتخاب رئيس جديد جماهير فريق حتجاج طالب استقال جماع مكتب رئيس نظيم احتجاج رئيس ملعب مسير موازا مبارا تزني درار جمهور شعار مناوئ مكتب مسير رئيس حقيق صعود ستغرب مفاجئ جماهير خلفي حقيق تساءل عديد مهتم محرك حقيقي احتجاج فريق حظوظ منافس صعود ثالث نهزم موسم رياض أصدر قدماء تزني طالب جماهير تعقل مسؤول فريق تائج طالب رئيس فريق تراجع استقال تطلب وحيد جهود حقيق صعود واحد رشيد تزني

# %%
x = 'ستوديوه رزاز صحراء مرزوك آثار رباط بيضاء نتهى مخرج مغرب سهيل صوير مشاهد سينمائ جديد سليط جاسوس إسبان دومينغ اديا تاسع مغرب فيلم ختار مخرج خليف عباس حياء متنكر تاجر سلال رسول فيما جاسوس حساب إسباني مخرج فيلم سهيل صريح هسبريس فيلم سينمائ مرحل توضيب خارج مغرب مبرز فيلم جاسوس إسبان دومينغ اديا مناطق عالم إسلام جاهز فيلم سينمائ ممثل مختلف ختار بطول ممثل سينمائ إيطال ارول ريشنتين قيام إنجليز هستر ستانهوب اشتهر زنوبي ارتبط علاق عاطف إضاف سينمائ معروف ختيار مخرج مغرب عباس صريح أنباء فرنس حداث مشوق ستحق أضواء مشير فيلم كثير مفاجآت امرأ طموح شجاع مثقف مذهل مستكشف إعجاب مقرب لحاق رحيل عباس مدين مسلم جميع مدين شييد مثال عروس شمال علوم ساعد إخفاء راجع معرف مغارب مسلم'
compare_all_dataset(x)
# Out:
# 0
# ('عالم نظيم نزال مغرب مغرب رياض وكسينغ عتبر أنسب انتقام منافس هولند رهوف ثلاثاء تصريح إعلام مواقع هولند متخصص رياض موعد انتقام قريب ملعب غلور منظم نزال شفائ إصاب تعرض نزال مجدد حقيق نزال احتضن ونيغ يلزينير مدين أوبيرهاوسن ألمان إصاب تراجع اعتزال انتقام هولند رهوف نزال غريم هولند انتقام طالب مقبل مشدد ملامح هزيم منتظر شفاء لتقي جديد صحاف هولند متابع متابع رياض ملاي مشاهد عتبر أكبر مغرب أخير متفوق مبارا منتخب مغرب إيفوار حساب مؤهل نهائ عالم روسي مسؤول إذاع تلفز مغرب مفاوض مبكر غلور مالك حقوق نزال سابق عالم إفريقي سياق مصادر مقرب مغرب كبير إقام نزال انتقام مغرب مضيف اعتزال مغارب',
#  17.0)
